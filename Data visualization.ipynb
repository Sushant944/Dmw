# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("corona.csv")

# %%
df.head(5)
# Out:
#        country continent  total_confirmed  total_deaths  total_recovered  \
# 0  Afghanistan      Asia           179267        7690.0         162202.0
# 1      Albania    Europe           275574        3497.0         271826.0
# 2      Algeria    Africa           265816        6875.0         178371.0
# 3      Andorra    Europe            42156         153.0          41021.0
# 4       Angola    Africa            99194        1900.0          97149.0
#
#    active_cases  serious_or_critical  total_cases_per_1m_population  \
# 0        9375.0               1124.0                           4420
# 1         251.0                  2.0                          95954
# 2       80570.0                  6.0                           5865
# 3         982.0                 14.0                         543983
# 4         145.0                  NaN                           2853
#
#    total_deaths_per_1m_population  total_tests  total_tests_per_1m_population  \
# ...

# %%
sb.countplot(data=df,x='continent')
# Out:
# <AxesSubplot:xlabel='continent', ylabel='count'>

# %%
sb.countplot(data=df,x='continent',hue='active_cases')
# Out:
# <AxesSubplot:xlabel='continent', ylabel='count'>

# %%
df['total_confirmed'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['total_confirmed'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.scatter(x='continent',y='total_confirmed')
# Out:
# <AxesSubplot:xlabel='continent', ylabel='total_confirmed'>

# %%
df.plot.hexbin(x='total_confirmed',y='total_deaths', gridsize=5)
# Out:
# <AxesSubplot:xlabel='total_confirmed', ylabel='total_deaths'>

# %%
df.plot.pie(x='continent',y='total_recovered')
# Out:
# <AxesSubplot:ylabel='total_recovered'>

# %%
ax=df.plot(figsize=(18,12), title='corona info')

# %%
sb.lineplot(x="population", y="total_deaths",data=df)
# Out:
# <AxesSubplot:xlabel='population', ylabel='total_deaths'>
